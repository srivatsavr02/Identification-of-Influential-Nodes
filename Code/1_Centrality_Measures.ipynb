# %% [markdown]
# # **Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from google.colab import drive
import csv
import networkx as nx

base_path="/content/gdrive/MyDrive/SNA/"
drive.mount('/content/gdrive')

df=pd.read_csv(base_path+"Dataset/SBCNDCTM.csv")
df
# Out:
# Mounted at /content/gdrive
#         9601108     1001
# 0       9601108  9602114
# 1       9601108  9603150
# 2       9601108  9603161
# 3       9601108  9608086
# 4       9601108  9609070
# ...         ...      ...
# 243712     7005   208052
# 243713     5057   208230
# 243714     7003   210113
# 243715     7093   211055
# 243716     6083   304062
#
# [243717 rows x 2 columns]

# %%
nodes=set()
edges=[]

for x, y in zip(df['9601108'], df['1001']):
  nodes.add(x)
  nodes.add(y)
  edges.append((x,y))

print("Edges: " + str(len(edges)))
print("Nodes: "+ str(len(nodes)))
# Out:
# Edges: 243717
# Nodes: 20262

# %%
print(nodes)
# Out:
# {9307025, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1057, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1100, 1101, 1102, 1103, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1148, 1149, 1150, 1151, 1152, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176
# ...

# %%
G = nx.DiGraph()

G.add_nodes_from(nodes)
G.add_edges_from(edges)

print(nx.info(G))
# Out:
# DiGraph with 20262 nodes and 243717 edges
# <ipython-input-11-64afd96e1726>:6: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(G))

# %% [markdown]
# # **Degree Centrality = Maximum Possible degree / n-1**

# %%
d=nx.degree_centrality(G)
print(d)
k1=[]
kv1= dict()
for key in d:
    k1.append([key,d[key]])
    kv1[key]=d[key]
# Out:
# {9307025: 4.935590543408519e-05, 1001: 0.003158777947781452, 1002: 0.003602981096688219, 1003: 0.000789694486945363, 1004: 9.871181086817038e-05, 1005: 0.0009871181086817038, 1006: 9.871181086817038e-05, 1007: 0.00014806771630225556, 1008: 9.871181086817038e-05, 1009: 9.871181086817038e-05, 1010: 0.0008390503923794482, 1011: 0.0011351858249839593, 1012: 0.0019248803119293223, 1013: 0.0013326094467203, 1014: 0.0004935590543408519, 1015: 4.935590543408519e-05, 1016: 0.0013326094467203, 1017: 0.0007403385815112778, 1018: 0.0013819653521543853, 1019: 0.0007403385815112778, 1020: 4.935590543408519e-05, 1021: 0.0006416267706431074, 1022: 0.00014806771630225556, 1023: 0.0006909826760771926, 1024: 0.0022210157445338337, 1025: 0.0017274566901929816, 1026: 4.935590543408519e-05, 1027: 0.003652337002122304, 1028: 0.0003454913380385963, 1029: 0.0015300330684566408, 1030: 0.00014806771630225556, 1031: 0.0003948472434726815, 1032: 0.002072948028231578, 1033: 0.008538571640096738, 1034: 0.000197423
# ...

# %%
fields=["Id","degree centrality"]
with open(base_path+"Results/degree_centrality.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k1:
         csvwriter.writerow(key)

# %%
from heapq import nlargest
res = nlargest(10, kv1, key = kv1.get)
print("Top 10 Nodes as per degree centrality are: ")
for val in res:
  print(val, kv1[val])
# Out:
# Top 10 Nodes as per degree centrality are:
# 9711200 0.12151423917871773
# 9802150 0.08854449434874882
# 9802109 0.08148659987167464
# 9905111 0.06524850698386062
# 9908142 0.059868713291545333
# 9610043 0.059375154237204485
# 9906064 0.05123142984058043
# 9711162 0.03973150387443858
# 9611050 0.0363259463994867
# 9601029 0.03213069443758946

# %% [markdown]
# # **Betweeness Centrality of v = sum of fraction of all pairs shortest paths that pass through v**

# %%
b=nx.betweenness_centrality(G)
print(b)
# Out:
# {9307025: 0.0, 1001: 9.558100471502591e-05, 1002: 0.000135088412176789, 1003: 1.3487735919749634e-08, 1004: 0.0, 1005: 1.4545890116255355e-05, 1006: 9.97835516429606e-05, 1007: 0.0, 1008: 0.0, 1009: 0.0, 1010: 5.309232784125006e-06, 1011: 1.947219195478517e-06, 1012: 4.019638939727643e-05, 1013: 2.3524581197675592e-05, 1014: 2.604044298480767e-07, 1015: 0.0, 1016: 9.165262051670818e-05, 1017: 0.0008061754845909284, 1018: 2.108779014241945e-05, 1019: 3.730272359611334e-05, 1020: 0.0, 1021: 5.088595483381721e-06, 1022: 4.14141358528849e-08, 1023: 0.00028188914631869415, 1024: 0.00020264081937669472, 1025: 2.3171484231307357e-05, 1026: 0.0, 1027: 0.00016029633900918158, 1028: 2.350936106444968e-07, 1029: 4.977274430240325e-05, 1030: 0.0, 1031: 1.4421655237861526e-06, 1032: 4.340040673311126e-06, 1033: 0.0021989422938813214, 1034: 0.0, 1035: 0.0002671005802953987, 1036: 3.3594261112950695e-08, 1037: 1.5242474032720685e-05, 1038: 0.0, 1039: 2.3407107175674654e-07, 1040: 2.4361256384049943
# ...

# %%
k2=[]
kv2=dict()
for key in b:
    k2.append([key,b[key]])
    kv2[key] = b[key]

fields=["Id","betweenness centrality"]
with open(base_path+"Results/betweenness_centrality.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k2:
         csvwriter.writerow(key)

from heapq import nlargest
res = nlargest(10, kv2, key = kv2.get)
print("Top 10 Nodes as per betweennes centrality are: ")
for val in res:
  print(val, kv2[val])
# Out:
# Top 10 Nodes as per betweennes centrality are:
# 9905111 0.11737916518311253
# 9810008 0.10874169781347577
# 206223 0.10864132910811432
# 9803001 0.07092007899495555
# 9902121 0.030471524972712834
# 3136 0.026437906349628067
# 9803076 0.023901655432161006
# 9712253 0.023063477562641252
# 206182 0.02181241926560882
# 9805154 0.021740279946334092

# %% [markdown]
# # **Eigenvector centrality computes the centrality for a node based on the centrality of its neighbors. The eigenvector centrality for node  is the i-th element of the vector.**

# %%
ev=nx.eigenvector_centrality(G)
print(ev)
# Out:
# {9307025: 6.860538441706093e-35, 1001: 8.143430058336916e-05, 1002: 0.003113014661649009, 1003: 3.47606975211047e-05, 1004: 6.860538441706093e-35, 1005: 1.4614141580104282e-05, 1006: 2.2159731305060623e-14, 1007: 2.773643288485947e-05, 1008: 2.2868461472353643e-36, 1009: 6.860538441706093e-35, 1010: 0.00012937906669681606, 1011: 2.7905278763263678e-05, 1012: 1.1787460000407298e-06, 1013: 0.000948896172816077, 1014: 3.233856050143049e-19, 1015: 5.06667229212255e-30, 1016: 0.0006238615459581467, 1017: 2.5493175413584726e-08, 1018: 0.0008926314346984708, 1019: 1.4772181124306557e-17, 1020: 6.860538441706093e-35, 1021: 1.7350207908157895e-18, 1022: 3.193886856897901e-17, 1023: 4.716595437394064e-06, 1024: 4.161977862739617e-05, 1025: 1.8691191139117647e-05, 1026: 1.9829471627292554e-31, 1027: 0.00010808785529903064, 1028: 3.182136908923678e-08, 1029: 2.450238103342089e-05, 1030: 2.012424609567121e-34, 1031: 2.395992495622578e-05, 1032: 4.913421830409231e-05, 1033: 0.007154577095070837, 1
# ...

# %%
k3=[]
for key in ev:
    k3.append([key,ev[key]])

fields=["Id","eigenvector centrality"]
with open(base_path+"Results/eigenvector_centrality.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k3:
         csvwriter.writerow(key)

from heapq import nlargest
res = nlargest(10, ev, key = ev.get)
print("Top 10 Nodes as per eigenvector centrality are: ")
for val in res:
  print(val, ev[val])
# Out:
# Top 10 Nodes as per eigenvector centrality are:
# 211178 0.3163665700874254
# 304232 0.2264903005837767
# 304025 0.15065526472756463
# 303060 0.14787458509492596
# 304114 0.14394720100172184
# 301250 0.14309771875905944
# 206062 0.14111230427488022
# 302064 0.12807494540662603
# 303223 0.12557970957226386
# 211217 0.11975526374038037

# %% [markdown]
# # **Closeness centrality of u = 1 / (Average shortest path distance to u over all n-1 reachable nodes)**

# %%
c=nx.closeness_centrality(G)
print(c)
# Out:
# {9307025: 4.935590543408519e-05, 1001: 0.059626985731406824, 1002: 0.07089313790722461, 1003: 0.05621493250184378, 1004: 4.935590543408519e-05, 1005: 0.049045669392571774, 1006: 0.010279972452552593, 1007: 0.056409847318051445, 1008: 0.0, 1009: 4.935590543408519e-05, 1010: 0.05072676693959692, 1011: 0.05873084736474164, 1012: 0.044024829031835126, 1013: 0.06422854754491762, 1014: 0.0016894732616637477, 1015: 0.0002362782706950887, 1016: 0.06887844158744162, 1017: 0.04127022303599641, 1018: 0.06491601403306287, 1019: 0.004419158672108596, 1020: 4.935590543408519e-05, 1021: 0.004024189876261378, 1022: 0.004183991074550595, 1023: 0.053410242322267674, 1024: 0.05899488058562185, 1025: 0.05257941024925233, 1026: 0.00011845417304180445, 1027: 0.05961036014142653, 1028: 0.04357652700875859, 1029: 0.05200070688625117, 1030: 0.00014806771630225556, 1031: 0.05784754728599617, 1032: 0.05787756338461951, 1033: 0.0714618628018564, 1034: 0.00022210157445338335, 1035: 0.047002755046795054, 1036: 0.
# ...

# %%
k4=[]
for key in c:
    k4.append([key,c[key]])

fields=["Id","closeness centrality"]
with open(base_path+"Results/closeness_centrality.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k4:
         csvwriter.writerow(key)

from heapq import nlargest
res = nlargest(10, c, key = c.get)
print("Top 10 Nodes as per eigenvector centrality are: ")
for val in res:
  print(val, c[val])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c4a929aa1d50> in <module>
#       1 k4=[]
# ----> 2 for key in c:
#       3     k4.append([key,c[key]])
#       4
#       5 fields=["Id","closeness centrality"]
#
# NameError: name 'c' is not defined

# %% [markdown]
# # **Hubs do not provide much information but links to pages in the root. Authorities contribute content and are linked by many Hubs pages related to that topic.**

# %%
hubs, authorities = nx.hits(G,max_iter=10000,normalized = True)

print(hubs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-6407051cb98c> in <module>
# ----> 1 hubs, authorities = nx.hits(G,max_iter=10000,normalized = True)
#       2
#       3 print(hubs)
#
# /usr/local/lib/python3.8/dist-packages/networkx/algorithms/link_analysis/hits_alg.py in hits(G, max_iter, tol, nstart, normalized)
#      76     if len(G) == 0:
#      77         return {}, {}
# ---> 78     A = nx.adjacency_matrix(G, nodelist=list(G), dtype=float)
#      79
#      80     if nstart is None:
#
# /usr/local/lib/python3.8/dist-packages/networkx/linalg/graphmatrix.py in adjacency_matrix(G, nodelist, dtype, weight)
#     171     )
#     172     # TODO: Change to `to_scipy_sparse_array` for networkx 3.0
# --> 173     return nx.to_scipy_sparse_matrix(G, nodelist=nodelist, dtype=dtype, weight=weight)
#     174
#     175
#
# ...

# %%
k5=[]
for key in hubs:
    k5.append([key,hubs[key]])

fields=["Id","hubscore"]
with open(base_path+"Results/hubscore.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k5:
         csvwriter.writerow(key)

k8=[]
for key in authorities:
    k8.append([key,authorities[key]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5aad0333c275> in <module>
#       1 k5=[]
# ----> 2 for key in hubs:
#       3     k5.append([key,hubs[key]])
#       4
#       5 fields=["Id","hubscore"]
#
# NameError: name 'hubs' is not defined

# %%
fields=["Id","authoritiesscore"]
with open(base_path+"Results/authorities_score.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k8:
         csvwriter.writerow(key)

print("Top 10 hubs: ")
res = nlargest(10, hubs, key = hubs.get)
for val in res:
  print(val, hubs[val])

# %%
print("Top 10 authorities: ")
res = nlargest(10, authorities, key = authorities.get)
for val in res:
  print(val, authorities[val])

# %% [markdown]
# # **Degree prestige = (number of incoming links to a node) / (total possible number of incoming links)**

# %%
n=len(nodes)

i = dict((v,len(G.edges(v))/(n-1)) for v in G.nodes())

k7=[]
for key in i:
    k7.append([key,i[key]])

fields=["Id","degree_prestige"]
with open(base_path+"Results/degree_prestige.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k7:
         csvwriter.writerow(key)

# %% [markdown]
# # **Proximity prestige = (proportion of vertices in the influence domain) / (mean distance from the vertices)**

# %%
distance = []

for dest in G.nodes:
    temp_dis = 0
    n = 0
    for src in G.nodes:
        if (nx.has_path(G,src,dest) == True):
            temp_dis = temp_dis + nx.shortest_path_length(G,source = src,target = dest)
            n = n + 1
    if temp_dis == 0:
        distance.append([dest, 0])
    else:
        distance.append([dest, temp_dis/(n - 1)])

distance

fields=["Id","Proximity-Prestige"]
with open(base_path+"Results/proximity_prestige.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in distance:
         csvwriter.writerow(key)

# %% [markdown]
# #**Rank Prestige**

# %%
n=len(nodes)

import numpy as np
prominance = np.random.randint(1, 4, size=n)
print("\nASSUME PROMINANCE :\n")
print(prominance)
# Out:
# ASSUME PROMINANCE :
#
# [3 1 1 ... 2 1 1]

# %%
rank_prestige = np.zeros([n], dtype = int)
path_matrix = np.zeros([n, n], dtype = int)

i = 0
j = 0
for src in G.nodes:
    for dest in G.nodes:
        if G.has_edge(dest, src):
            path_matrix[i][j] = 1
        j = j+1
    j = 0
    i = i+1

link=[]
for i in range(n):
    pr_i = 0
    for j in range(n):
        pr_i = pr_i + path_matrix[i][j] * prominance[j]
    rank_prestige[i] = pr_i
    link.append([i,rank_prestige[i]])

print(len(rank_prestige))
# Out:
# 20262

# %%
fields=["Id","rank-Prestige"]
with open(base_path+"Results/rank_Prestige.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in link:
         csvwriter.writerow(key)

# %% [markdown]
# # **PageRank computes a ranking of the nodes in the graph G based on the structure of the incoming links.**

# %%
value=nx.pagerank(G)

k=[]
for key in value:
    k.append([key,value[key]])

fields=["Id","Page-Rank"]
with open(base_path+"Results/page_rank.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k:
         csvwriter.writerow(key)
print("Top 10 nodes as per Page rank: ")
res = nlargest(10, value, key = value.get)
for val in res:
  print(val, value[val])
# Out:
# Top 10 nodes as per Page rank:
# 207116 0.0012357930715754565
# 303256 0.0010740303014596185
# 304263 0.0010526786329588778
# 9905111 0.0010291577878273844
# 304187 0.0009364385057723052
# 211178 0.0009259754562206087
# 210157 0.0008614140675558323
# 304131 0.0008356450360636864
# 204089 0.0007996501995776272
# 304262 0.0007934091591747764

# %% [markdown]
# # **Katz centrality computes the centrality for a node based on the centrality of its neighbors. It is a generalization of the eigenvector centrality.**

# %%
value=nx.katz_centrality(G)
k=[]
for key in value:
    k.append([key,value[key]])

fields=["Id","Katz-Centrality"]
with open(base_path+"Results/katz_centrality.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k:
         csvwriter.writerow(key)

print("Top 10 nodes as per Katz: ")
res = nlargest(10, value, key = value.get)
for val in res:
  print(val, value[val])

# %% [markdown]
# # **Percolation states of nodes are used to depict network percolation scenarios over time. In this measure usually the percolation state is expressed as a decimal between 0.0 and 1.0.**

# %%
from networkx.algorithms.centrality.percolation import percolation_centrality
nx.set_node_attributes(G,0.1,'percolation')

value=percolation_centrality(G,attribute='percolation')

k=[]
for key in value:
    k.append([key,value[key]])

fields=["Id","Percolation-Centrality"]
with open(base_path+"Results/percolation_centrality.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k:
         csvwriter.writerow(key)

print("Top 10 percolation centralities: ")
res = nlargest(10, value, key = value.get)
for val in res:
  print(val, value[val])

# %% [markdown]
# # **Harmonic centrality of u = sum of the reciprocal of the shortest path distances from all other nodes to u**

# %%
from networkx.algorithms.centrality.harmonic import harmonic_centrality
hc=harmonic_centrality(G)

k15=[]
for key in hc:
    k15.append([key,hc[key]])

fields=["Id","Harmonic centrality"]
with open(base_path+"Results/harmonic_centrality.csv",'w') as csvFile:
     csvwriter=csv.writer(csvFile)
     csvwriter.writerow(fields)
     for key in k15:
         csvwriter.writerow(key)

print("Top 10 Harmonic Centralities: ")
res = nlargest(10, hc, key = hc.get)
for val in res:
  print(val, hc[val])
# Out:
# Top 10 Harmonic Centralities:
# 210224 3379.3506132757066
# 210157 3144.8439436982317
# 210292 3138.776165501218
# 209241 3027.2045954046375
# 110055 3004.1823696458073
# 211178 2981.878463203505
# 207116 2956.9597064513378
# 207249 2938.9008390474582
# 303072 2937.1223940965124
# 303191 2922.1990204240315
